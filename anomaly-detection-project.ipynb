# %% [markdown]
# # Anomaly detection project
#
# Hello,
#
#
# I have some questions for you that I need to be answered before the board meeting Thursday afternoon. I need to be able to speak to the following questions. I also need a single slide that I can incorporate into my existing presentation (Google Slides) that summarizes the most important points. My questions are listed below; however, if you discover anything else important that I didn’t think to ask, please include that as well.
#
#
# 1. Which lesson appears to attract the most traffic consistently across cohorts (per program)?
# 2. Is there a cohort that referred to a lesson significantly more than other cohorts seemed to gloss over?
# 3. Are there students who, when active, hardly access the curriculum? If so, what information do you have about these students?
# 4. Is there any suspicious activity, such as users/machines/etc accessing the curriculum who shouldn’t be? Does it appear that any web-scraping is happening? Are there any suspicious IP addresses?
# 5. At some point in 2019, the ability for students and alumni to access both curriculums (web dev to ds, ds to web dev) should have been shut off. Do you see any evidence of that happening? Did it happen before?
# 6. What topics are grads continuing to reference after graduation and into their jobs (for each program)?
# 7. Which lessons are least accessed?
# 8. Anything else I should be aware of?
#
#
# Thank you

# %%
#Import dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from env import host, username, password

# %%
#Define a function that creates the database url
def url_creator(host, username, password, db_name):
    return f'mysql+pymysql://{username}:{password}@{host}/{db_name}'

# %%
#Create the url
url = url_creator(host, username, password, 'curriculum_logs')

# %%
#Define the SQL query
query = '''
        SELECT date,
        time, path as endpoint,
        user_id,
        cohort_id,
        ip, name,
        slack, start_date,
        end_date, created_at,
        updated_at, deleted_at,
        program_id
        FROM logs
        LEFT JOIN cohorts ON logs.cohort_id = cohorts.id
        '''

# %%
#Read in the dataframe
df = pd.read_sql(query, url)
df.head()
# Out:
#          date      time                             endpoint  user_id  \
# 0  2018-01-26  09:55:03                                    /        1
# 1  2018-01-26  09:56:02                              java-ii        1
# 2  2018-01-26  09:56:05  java-ii/object-oriented-programming        1
# 3  2018-01-26  09:56:06   slides/object_oriented_programming        1
# 4  2018-01-26  09:56:24            javascript-i/conditionals        2
#
#    cohort_id            ip     name     slack  start_date    end_date  \
# 0        8.0  97.105.19.61  Hampton  #hampton  2015-09-22  2016-02-06
# 1        8.0  97.105.19.61  Hampton  #hampton  2015-09-22  2016-02-06
# 2        8.0  97.105.19.61  Hampton  #hampton  2015-09-22  2016-02-06
# 3        8.0  97.105.19.61  Hampton  #hampton  2015-09-22  2016-02-06
# 4       22.0  97.105.19.61    Teddy    #teddy  2018-01-08  2018-05-17
#
#             created_at           updated_at deleted_at  program_id
# 0  2016-06-14 19:52:26  2016-06-14 19:52:26       None         1.0
# 1  2016-06-14 19:52:26  2016-06-14 19:52:26       None         1.0
# 2  2016-06-14 19:52:26  2016-06-14 19:52:26       None         1.0
# 3  2016-06-14 19:52:26  2016-06-14 19:52:26       None         1.0
# 4  2018-01-08 13:59:10  2018-01-08 13:59:10       None         2.0

# %%
#Check the shape
df.shape
# Out:
# (900223, 14)

# %%
#Look at the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900223 entries, 0 to 900222
# Data columns (total 14 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        900223 non-null  object
#  1   time        900223 non-null  object
#  2   endpoint    900222 non-null  object
#  3   user_id     900223 non-null  int64
#  4   cohort_id   847330 non-null  float64
#  5   ip          900223 non-null  object
#  6   name        847330 non-null  object
#  7   slack       847330 non-null  object
#  8   start_date  847330 non-null  object
#  9   end_date    847330 non-null  object
#  10  created_at  847330 non-null  object
#  11  updated_at  847330 non-null  object
#  12  deleted_at  0 non-null       object
#  13  program_id  847330 non-null  float64
# dtypes: float64(2), int64(1), object(11)
# memory usage: 96.2+ MB

# %% [markdown]
# I have some nulls in my dataframe that I would like to investigate before I begin answering the questions. Many columns have the same non-null value counts. Are these columns all missing information for the same group of observations?

# %%
#Drop the column with all null values
df.drop(columns=['deleted_at'], inplace=True)

# %%
#Rows with null cohort id
df[df['cohort_id'].isna()]
# Out:
#               date      time                               endpoint  user_id  \
# 411     2018-01-26  16:46:16                                      /       48
# 412     2018-01-26  16:46:24  spring/extra-features/form-validation       48
# 425     2018-01-26  17:54:24                                      /       48
# 435     2018-01-26  18:32:03                                      /       48
# 436     2018-01-26  18:32:17              mysql/relationships/joins       48
# ...            ...       ...                                    ...      ...
# 899897  2021-04-21  12:49:00                          javascript-ii      717
# 899898  2021-04-21  12:49:02                      javascript-ii/es6      717
# 899899  2021-04-21  12:51:27        javascript-ii/map-filter-reduce      717
# 899900  2021-04-21  12:52:37                 javascript-ii/promises      717
# 899902  2021-04-21  12:56:26              javascript-ii/RESTful-api      717
#
#         cohort_id              ip  name slack start_date end_date created_at  \
# 411           NaN    97.105.19.61  None  None       None     None       None
# 412           NaN    97.105.19.61  None  None       None     None       None
# 425           NaN    97.105.19.61  None  None       None     None       None
# 435           NaN    97.105.19.61  None  None       None     None       None
# 436           NaN    97.105.19.61  None  None       None     None       None
# ...           ...             ...   ...   ...        ...      ...        ...
# 899897        NaN  136.50.102.126  None  None       None     None       None
# 899898        NaN  136.50.102.126  None  None       None     None       None
# 899899        NaN  136.50.102.126  None  None       None     None       None
# 899900        NaN  136.50.102.126  None  None       None     None       None
# 899902        NaN  136.50.102.126  None  None       None     None       None
#
#        updated_at  program_id
# 411          None         NaN
# 412          None         NaN
# 425          None         NaN
# 435          None         NaN
# 436          None         NaN
# ...           ...         ...
# 899897       None         NaN
# 899898       None         NaN
# 899899       None         NaN
# 899900       None         NaN
# 899902       None         NaN
#
# [52893 rows x 13 columns]

# %%
#Are the nulls from all columns present in these observations?
df[df['cohort_id'].isna()].isna().sum()
# Out:
# date              0
# time              0
# endpoint          0
# user_id           0
# cohort_id     52893
# ip                0
# name          52893
# slack         52893
# start_date    52893
# end_date      52893
# created_at    52893
# updated_at    52893
# program_id    52893
# dtype: int64

# %%
#Check out the one endpoint null
df[df.endpoint.isna()]
# Out:
#               date      time endpoint  user_id  cohort_id             ip  \
# 506305  2020-04-08  09:25:18     None      586       55.0  72.177.240.51
#
#          name   slack  start_date    end_date           created_at  \
# 506305  Curie  #curie  2020-02-03  2020-07-07  2020-02-03 19:31:51
#
#                  updated_at  program_id
# 506305  2020-02-03 19:31:51         3.0

# %%
#Create a module lesson with the first portion of the endpoint
df['module'] = df['endpoint'].str.split('/').str[0]

# %%
#Create a lesson column with the last portion of the endpoint
df['lesson'] = df['endpoint'].str.split('/').str[-1]

# %%
df['is_lesson'] = (df['module'] != df['lesson'])

# %%
df
# Out:
#               date      time  \
# 0       2018-01-26  09:55:03
# 1       2018-01-26  09:56:02
# 2       2018-01-26  09:56:05
# 3       2018-01-26  09:56:06
# 4       2018-01-26  09:56:24
# ...            ...       ...
# 900218  2021-04-21  16:41:51
# 900219  2021-04-21  16:42:02
# 900220  2021-04-21  16:42:09
# 900221  2021-04-21  16:44:37
# 900222  2021-04-21  16:44:39
#
#                                                 endpoint  user_id  cohort_id  \
# 0                                                      /        1        8.0
# 1                                                java-ii        1        8.0
# 2                    java-ii/object-oriented-programming        1        8.0
# 3                     slides/object_oriented_programming        1        8.0
# 4                              javascript-i/conditionals        2       22.0
# ...                                                  ...      ...        ...
# 900218                              jquery/personal-site       64       28.0
# 900219                                 jquery/mapbox-api       64       28.0
# 900220                           jquery/ajax/weather-map       64       28.0
# 900221  anomaly-detection/discrete-probabilistic-methods      744       28.0
# 900222                                 jquery/mapbox-api       64       28.0
#
#                    ip     name     slack  start_date    end_date  \
# 0        97.105.19.61  Hampton  #hampton  2015-09-22  2016-02-06
# 1        97.105.19.61  Hampton  #hampton  2015-09-22  2016-02-06
# 2        97.105.19.61  Hampton  #hampton  2015-09-22  2016-02-06
# 3        97.105.19.61  Hampton  #hampton  2015-09-22  2016-02-06
# 4        97.105.19.61    Teddy    #teddy  2018-01-08  2018-05-17
# ...               ...      ...       ...         ...         ...
# 900218  71.150.217.33    Staff         #  2014-02-04  2014-02-04
# 900219  71.150.217.33    Staff         #  2014-02-04  2014-02-04
# 900220  71.150.217.33    Staff         #  2014-02-04  2014-02-04
# 900221  24.160.137.86    Staff         #  2014-02-04  2014-02-04
# 900222  71.150.217.33    Staff         #  2014-02-04  2014-02-04
#
#                  created_at           updated_at  program_id  \
# 0       2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
# 1       2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
# 2       2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
# 3       2016-06-14 19:52:26  2016-06-14 19:52:26         1.0
# 4       2018-01-08 13:59:10  2018-01-08 13:59:10         2.0
# ...                     ...                  ...         ...
# 900218  2018-12-06 17:04:19  2018-12-06 17:04:19         2.0
# 900219  2018-12-06 17:04:19  2018-12-06 17:04:19         2.0
# 900220  2018-12-06 17:04:19  2018-12-06 17:04:19         2.0
# 900221  2018-12-06 17:04:19  2018-12-06 17:04:19         2.0
# 900222  2018-12-06 17:04:19  2018-12-06 17:04:19         2.0
#
#                    module                          lesson  is_lesson
# 0                                                              False
# 1                 java-ii                         java-ii      False
# 2                 java-ii     object-oriented-programming       True
# 3                  slides     object_oriented_programming       True
# 4            javascript-i                    conditionals       True
# ...                   ...                             ...        ...
# 900218             jquery                   personal-site       True
# 900219             jquery                      mapbox-api       True
# 900220             jquery                     weather-map       True
# 900221  anomaly-detection  discrete-probabilistic-methods       True
# 900222             jquery                      mapbox-api       True
#
# [900223 rows x 16 columns]

# %% [markdown]
# ## Question 1
#
# Which lesson appears to attract the most traffic consistently across cohorts (per program)?

# %%
df['program_id'].value_counts()
# Out:
# 2.0    713365
# 3.0    103412
# 1.0     30548
# 4.0         5
# Name: program_id, dtype: int64

# %% [markdown]
# Four unique program IDs. I need to map real programs to the appropriate ID using alumni.codeup.com. I will accomplish this by looking up the cohorts associated with each ID and mapping the program name to all cohorts with the same program ID.

# %%
for i in range(1, 5):
    print()
    print('--------------------------------')
    print()
    print('Program ID {} corresponds to these cohorts.'.format(i))
    print()
    print(df[df['program_id'] == i]['name'].unique())
# Out:
# --------------------------------
#
# Program ID 1 corresponds to these cohorts.
#
# ['Hampton' 'Arches' 'Quincy' 'Kings' 'Lassen' 'Glacier' 'Denali' 'Joshua'
#  'Olympic' 'Badlands' 'Ike' 'Franklin' 'Everglades']
#
# --------------------------------
#
# Program ID 2 corresponds to these cohorts.
#
# ['Teddy' 'Sequoia' 'Niagara' 'Pinnacles' 'Mammoth' 'Ulysses' 'Voyageurs'
#  'Wrangell' 'Xanadu' 'Yosemite' 'Staff' 'Zion' 'Andromeda' 'Betelgeuse'
#  'Ceres' 'Deimos' 'Europa' 'Fortuna' 'Apex' 'Ganymede' 'Hyperion' 'Bash'
#  'Jupiter' 'Kalypso' 'Luna' 'Marco' 'Neptune' 'Oberon']
#
# --------------------------------
#
# Program ID 3 corresponds to these cohorts.
#
# ['Bayes' 'Curie' 'Darden' 'Easley' 'Florence']
#
# --------------------------------
#
# Program ID 4 corresponds to these cohorts.
#
# ['Apollo']

# %% [markdown]
# Programs with ID 1 map to "Full Stack PHP Program." These programs represent early cohorts at Codeup that learned web development. Cohorts belonging to this program ID will be labeled "PHP".
#
# Programs with ID 2 map to "Full Stack Java Program." These programs also train web developers, but are more recent cohorts in Codeup's history. These cohorts will be labeled "Java" moving forward.
#
# Programs with ID 3 map to "Data Science Program." These cohorts will be labeled "DS".
#
# Programs with ID 4 map to "Front-End Program." I will label this lone cohort "Front".

# %%
program_dict = {1.0: 'PHP', 2.0: 'Java', 3.0: 'DS', 4.0: 'Front'}

df['program_type'] = df['program_id'].map(program_dict)

# %%
#The program id column is now worthless
df.drop(columns=['program_id'], inplace=True)

# %%
program_list = ['PHP', 'Java', 'DS', 'Front']

for program in program_list:
    print()
    print('--------------------------------')
    print()
    print('Most visited pages by members of the {} program.'.format(program))
    print()
    print(df[df['program_type'] == program]['lesson'].value_counts().head(10))
# Out:
# --------------------------------
#
# Most visited pages by members of the PHP program.
#
#                 1681
# favicon.ico     1239
# index.html      1020
# html-css         814
# javascript-i     736
# introduction     562
# spring           501
# java-iii         479
# appendix         469
# java-ii          454
# Name: lesson, dtype: int64
#
# --------------------------------
#
# Most visited pages by members of the Java program.
#
#                      35814
# introduction         20114
# javascript-i         17457
# toc                  17428
# search_index.json    16976
# html-css             12913
# java-iii             12684
# java-ii              11719
# spring               11385
# jquery               10710
# Name: lesson, dtype: int64
#
# --------------------------------
#
# Most visited pages by members of the DS program.
#
#                              8358
# overview                     4267
# 1-overview                   3519
# modern-data-scientist.jpg    3152
# AI-ML-DL-timeline.jpg        3152
# project                      3140
# search_index.json            2204
# 1.1-intro-to-data-science    1633
# explore                      1595
# scale_features_or_not.svg    1594
# Name: lesson, dtype: int64
#
# --------------------------------
#
# Most visited pages by members of the Front program.
#
# html-css             2
#                      1
# favicon.ico          1
# introduction.html    1
# Name: lesson, dtype: int64

# %% [markdown]
# The PHP and Java programs share a great amount of topics in common: java, javascript, spring, and html. The data science students often refer to classification and fundamentals information. Members of the Front program account for 5 total hits on webpages.
#
# I don't think this answers the question in its entirety. The question asks about consistent traffic across cohorts. I will need to group by cohort within each program to answer the question completely.

# %%
#Create separate dataframes for each program
df_php = df[df['program_type'] == 'PHP']
df_java = df[df['program_type'] == 'Java']
df_ds = df[df['program_type'] == 'DS']

# %%
df_php[df_php['name'] == 'Quincy'].module.value_counts().iloc[:5]
# Out:
# content    650
#            151
# mysql       97
# java-i      50
# slides      49
# Name: module, dtype: int64

# %%
def most_visited_modules(df):
    
    mv = pd.DataFrame()
    
    cohort_list = list(df['name'].unique())
    
    for cohort in cohort_list:
        
        if len(df[df['name'] == cohort].module.value_counts().iloc[:5].index) < 5:
            
            continue
            
        else:    
        
            mv[cohort] = df[df['name'] == cohort].module.value_counts().iloc[:5].index
        
    return mv

# %%
def most_popular_modules(df):
    
    mv = most_visited_modules(df)
    
    top_five = mv.melt(var_name='columns', value_name='index')['index'].value_counts().head(5)
    
    return top_five

# %%
most_popular_modules(df_php)
# Out:
# content         8
#                 7
# javascript-i    7
# html-css        6
# java-iii        4
# Name: index, dtype: int64

# %%
most_popular_modules(df_java)
# Out:
# javascript-i    27
# html-css        25
# mysql           24
# jquery          14
# spring          13
# Name: index, dtype: int64

# %%
most_popular_modules(df_ds)
# Out:
#                   4
# 1-fundamentals    3
# classification    3
# sql               3
# python            3
# Name: index, dtype: int64

# %% [markdown]
# For PHP cohorts, the content, javascript-i, and html-css modules are the most popular.
#
# For Java cohorts, the javascript-i, html-css, and mysql modules are the most popular.
#
# For DS cohorts, the fundamentals, classification, sql, and python modules are the most popular.

# %%
df_php[df_php['name'] == 'Quincy'].loc[df_php.is_lesson].lesson.value_counts().head(10)
# Out:
# favicon.ico                   92
# intro                         38
# html-css                      33
# environment.html              31
# application-structure.html    20
# intro-to-mysql                19
# php_iii                       19
# introduction                  17
# conditionals                  16
# collections                   15
# Name: lesson, dtype: int64

# %%
def most_visited_lessons(df):
    
    mv = pd.DataFrame()
    
    cohort_list = list(df['name'].unique())
    
    for cohort in cohort_list:
        
        if len(df[df['name'] == cohort].loc[df.is_lesson].lesson.value_counts().iloc[:5].index) < 5:
            
            continue
            
        else:    
        
            mv[cohort] = df[df['name'] == cohort].loc[df.is_lesson].lesson.value_counts().iloc[:5].index
        
    return mv

# %%
def most_popular_lessons(df):
    
    mv = most_visited_lessons(df)
    
    top_five = mv.melt(var_name='columns', value_name='index')['index'].value_counts().head(5)
    
    return top_five

# %%
most_popular_lessons(df_php)
# Out:
# favicon.ico          7
# html-css             5
# introduction         5
# intro                2
# introduction.html    2
# Name: index, dtype: int64

# %%
most_popular_lessons(df_java)
# Out:
# introduction         26
# functions            23
# search_index.json    22
# arrays               19
# servlets              4
# Name: index, dtype: int64

# %%
most_popular_lessons(df_ds)
# Out:
# project                      4
# AI-ML-DL-timeline.jpg        4
# modern-data-scientist.jpg    3
# 1-overview                   2
# overview                     2
# Name: index, dtype: int64

# %% [markdown]
# For PHP, the most popular lessons across all cohorts are html-css and introductions.
#
# For Java, the most popular lessons across all cohorts are introductions, functions, and arrays.
#
# For DS, the most popular lessons across all cohorts are projects, the timeline, and the modern data scientist.

# %% [markdown]
# ## Question 2
#
# Is there a cohort that referred to a lesson significantly more than other cohorts seemed to gloss over?

# %%
df_php[df_php.is_lesson].lesson.value_counts().head(10)
# Out:
# favicon.ico                                        1239
# introduction                                        560
# arrays                                              346
# functions                                           322
# html-css                                            272
# servlets                                            272
# mvc                                                 259
# jdbc                                                243
# intro                                               241
# working-with-data-types-operators-and-variables     232
# Name: lesson, dtype: int64

# %%
php_mp_list = ['arrays', 'functions', 'html-css', 'servlets', 'mvc', 'jdbc',
               'working-with-data-types-operators-and-variables']

for pop in php_mp_list:
    
    print()
    print('--------------------------------')
    print()
    print('How many times each cohort accessed the {} lesson.'.format(pop))
    print()
    print(df_php[df_php['lesson'] == pop].name.value_counts())
# Out:
# --------------------------------
#
# How many times each cohort accessed the arrays lesson.
#
# Arches     143
# Lassen     118
# Olympic     59
# Hampton      9
# Quincy       8
# Kings        7
# Joshua       1
# Glacier      1
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the functions lesson.
#
# Lassen      109
# Arches      107
# Olympic      54
# Hampton      20
# Glacier      20
# Quincy        5
# Kings         3
# Ike           3
# Franklin      1
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the html-css lesson.
#
# Lassen      237
# Arches      227
# Olympic     129
# Kings        55
# Glacier      50
# Quincy       45
# Joshua       24
# Hampton      22
# Ike          21
# Badlands      3
# Franklin      1
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the servlets lesson.
#
# Lassen      120
# Arches       79
# Hampton      38
# Olympic      29
# Kings         4
# Glacier       1
# Franklin      1
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the mvc lesson.
#
# Lassen     114
# Arches     100
# Hampton     30
# Olympic     16
# Kings        2
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the jdbc lesson.
#
# Lassen      105
# Arches       92
# Hampton      35
# Olympic       9
# Glacier       1
# Franklin      1
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the working-with-data-types-operators-and-variables lesson.
#
# Arches     71
# Olympic    65
# Lassen     57
# Glacier    24
# Hampton     9
# Kings       4
# Quincy      1
# Ike         1
# Name: name, dtype: int64

# %% [markdown]
# At first glance, Arches and Lassen are dominating the number of hits on each lesson page. What could be driving this behavior?

# %%
df_php.name.value_counts()
# Out:
# Lassen        9587
# Arches        8890
# Olympic       4954
# Kings         2845
# Hampton       1712
# Quincy        1237
# Glacier        598
# Joshua         302
# Ike            253
# Badlands        93
# Franklin        72
# Denali           4
# Everglades       1
# Name: name, dtype: int64

# %% [markdown]
# Lassen and Arches also dominate the overall number of impressions on the curriculum website. Given their activity relative to the other cohorts, I don't identify much any anomalous behavior across the most popular lessons for PHP developers. The only thing that catches my eye is how many times the Olympic cohort accessed the working-with-data-types-operators-and-variables lesson. They beat out Lassen and almost took the top spot.

# %%
df_java[df_java.is_lesson].lesson.value_counts().head(10)
# Out:
# introduction                                       20069
# search_index.json                                  16976
# arrays                                             10504
# functions                                          10174
# working-with-data-types-operators-and-variables     7109
# tables                                              7027
# javascript-with-html                                6824
# servlets                                            6622
# databases                                           6574
# elements                                            6522
# Name: lesson, dtype: int64

# %%
java_mp_list = ['arrays', 'functions', 'working-with-data-types-operators-and-variables', 'tables',
              'javascript-with-html', 'servlets', 'databases', 'elements']

for pop in java_mp_list:
    
    print()
    print('--------------------------------')
    print()
    print('How many times each cohort accessed the {} lesson.'.format(pop))
    print()
    print(df_java[df_java['lesson'] == pop].name.value_counts())
# Out:
# --------------------------------
#
# How many times each cohort accessed the arrays lesson.
#
# Ceres         733
# Fortuna       701
# Voyageurs     628
# Staff         580
# Teddy         573
# Zion          555
# Betelgeuse    554
# Ulysses       553
# Jupiter       527
# Apex          491
# Ganymede      490
# Deimos        428
# Hyperion      417
# Xanadu        414
# Kalypso       390
# Andromeda     390
# Wrangell      370
# Europa        344
# Luna          299
# Yosemite      288
# Bash          278
# Marco         276
# Neptune       137
# Sequoia        64
# Pinnacles      14
# Mammoth         7
# Niagara         6
# Oberon          3
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the functions lesson.
#
# Staff         681
# Ceres         614
# Zion          550
# Teddy         543
# Jupiter       526
# Ganymede      467
# Voyageurs     465
# Ulysses       460
# Xanadu        459
# Betelgeuse    451
# Fortuna       447
# Deimos        445
# Wrangell      419
# Apex          406
# Hyperion      404
# Marco         386
# Europa        349
# Yosemite      344
# Andromeda     339
# Kalypso       331
# Luna          311
# Bash          278
# Neptune       220
# Oberon        171
# Sequoia        75
# Pinnacles      37
# Mammoth         4
# Niagara         3
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the working-with-data-types-operators-and-variables lesson.
#
# Marco         511
# Ceres         423
# Hyperion      382
# Jupiter       362
# Zion          356
# Neptune       331
# Voyageurs     330
# Betelgeuse    327
# Luna          319
# Europa        319
# Fortuna       295
# Andromeda     294
# Deimos        292
# Staff         285
# Wrangell      283
# Ulysses       276
# Apex          270
# Ganymede      257
# Xanadu        241
# Kalypso       237
# Teddy         176
# Bash          176
# Yosemite      173
# Oberon        146
# Sequoia        36
# Pinnacles      11
# Niagara         1
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the tables lesson.
#
# Staff         458
# Jupiter       439
# Voyageurs     437
# Zion          400
# Teddy         387
# Deimos        381
# Fortuna       380
# Ceres         378
# Xanadu        374
# Apex          352
# Europa        342
# Betelgeuse    337
# Andromeda     318
# Ulysses       309
# Yosemite      283
# Wrangell      282
# Hyperion      282
# Ganymede      265
# Kalypso       217
# Luna          183
# Bash          151
# Sequoia        65
# Pinnacles      13
# Marco           4
# Niagara         2
# Mammoth         2
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the javascript-with-html lesson.
#
# Ceres         423
# Marco         420
# Betelgeuse    367
# Zion          364
# Jupiter       360
# Voyageurs     354
# Ulysses       321
# Neptune       311
# Staff         310
# Wrangell      302
# Hyperion      289
# Fortuna       287
# Xanadu        267
# Deimos        266
# Andromeda     257
# Apex          254
# Ganymede      250
# Europa        238
# Yosemite      230
# Luna          207
# Kalypso       197
# Bash          186
# Teddy         185
# Oberon        125
# Sequoia        49
# Pinnacles      18
# Niagara         3
# Mammoth         2
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the servlets lesson.
#
# Staff         548
# Voyageurs     478
# Fortuna       429
# Jupiter       418
# Teddy         385
# Apex          359
# Ganymede      349
# Ceres         337
# Deimos        329
# Zion          329
# Ulysses       315
# Hyperion      302
# Andromeda     270
# Betelgeuse    264
# Europa        249
# Kalypso       247
# Xanadu        231
# Wrangell      225
# Bash          174
# Luna          160
# Yosemite      155
# Sequoia        32
# Pinnacles      15
# Niagara        14
# Mammoth         6
# Marco           4
# Neptune         3
# Oberon          1
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the databases lesson.
#
# Voyageurs     439
# Jupiter       398
# Teddy         383
# Staff         377
# Zion          375
# Deimos        365
# Ceres         356
# Europa        337
# Ulysses       326
# Fortuna       325
# Apex          321
# Xanadu        318
# Betelgeuse    293
# Ganymede      292
# Andromeda     292
# Hyperion      283
# Wrangell      235
# Kalypso       229
# Yosemite      229
# Luna          167
# Bash          165
# Sequoia        68
# Pinnacles      10
# Marco           5
# Mammoth         4
# Niagara         4
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the elements lesson.
#
# Betelgeuse    495
# Xanadu        438
# Europa        430
# Ceres         411
# Hyperion      386
# Zion          347
# Voyageurs     342
# Staff         318
# Jupiter       310
# Fortuna       290
# Marco         287
# Deimos        272
# Wrangell      254
# Andromeda     253
# Kalypso       239
# Ganymede      238
# Apex          225
# Ulysses       214
# Yosemite      207
# Luna          163
# Neptune       152
# Sequoia       109
# Bash          106
# Teddy          78
# Pinnacles      11
# Niagara         3
# Name: name, dtype: int64

# %% [markdown]
# There are no Java cohorts accessing a particular lesson significantly more than the others. I will look at the overall number of hits by each cohort to be sure.

# %%
df_java.name.value_counts()
# Out:
# Staff         84031
# Ceres         40730
# Zion          38096
# Jupiter       37109
# Fortuna       36902
# Voyageurs     35636
# Ganymede      33844
# Apex          33568
# Deimos        32888
# Teddy         30926
# Hyperion      29855
# Betelgeuse    29356
# Ulysses       28534
# Europa        28033
# Xanadu        27749
# Wrangell      25586
# Andromeda     25359
# Kalypso       23691
# Yosemite      20743
# Bash          17713
# Luna          16623
# Marco         16397
# Sequoia        7444
# Neptune        7276
# Pinnacles      2158
# Oberon         1672
# Niagara         755
# Mammoth         691
# Name: name, dtype: int64

# %% [markdown]
# Interestingly enough, the Codeup staff dominate the overall impressions on the Java curriculum website. This makes sense, because staff members are constantly accessing the curriculum to answer questions, prepare for lectures, and improve the material. An interesting note is the PHP subset didn't have any labeled staff members.

# %%
df_ds[df_ds.is_lesson].lesson.value_counts().head(10)
# Out:
# overview                        4259
# 1-overview                      3517
# project                         3137
# modern-data-scientist.jpg       3094
# AI-ML-DL-timeline.jpg           3094
# search_index.json               2204
# 1.1-intro-to-data-science       1633
# scale_features_or_not.svg       1590
# explore                         1585
# AnomalyDetectionCartoon.jpeg    1583
# Name: lesson, dtype: int64

# %% [markdown]
# The data science curriculum has less descriptive lesson names than the other programs. "Overview", "Project", and "Explore" likely exist under multiple modules. I will disregard them for this analysis because I can't pinpoint their content.

# %%
ds_mp_list = ['modern-data-scientist.jpg', 'AI-ML-DL-timeline.jpg', '1.1-intro-to-data-science',
              'scale_features_or_not.svg', 'AnomalyDetectionCartoon.jpeg']

for pop in ds_mp_list:
    
    print()
    print('--------------------------------')
    print()
    print('How many times each cohort accessed the {} lesson.'.format(pop))
    print()
    print(df_ds[df_ds['lesson'] == pop].name.value_counts())
# Out:
# --------------------------------
#
# How many times each cohort accessed the modern-data-scientist.jpg lesson.
#
# Darden      808
# Florence    704
# Bayes       675
# Curie       568
# Easley      397
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the AI-ML-DL-timeline.jpg lesson.
#
# Darden      812
# Florence    701
# Bayes       673
# Curie       567
# Easley      399
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the 1.1-intro-to-data-science lesson.
#
# Bayes       640
# Curie       461
# Darden      460
# Florence     64
# Easley        8
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the scale_features_or_not.svg lesson.
#
# Darden      944
# Easley      463
# Curie        96
# Florence     60
# Bayes        31
# Name: name, dtype: int64
#
# --------------------------------
#
# How many times each cohort accessed the AnomalyDetectionCartoon.jpeg lesson.
#
# Darden      635
# Curie       421
# Bayes       402
# Easley      111
# Florence     18
# Name: name, dtype: int64

# %% [markdown]
# The Darden cohort accessed almost all popular lessons much more frequently than the other cohorts. Bayes stands out on the intro to data science lesson. Could Darden's dominance be explained by overall greater activity on the website?

# %%
df_ds.name.value_counts()
# Out:
# Darden      32015
# Bayes       26538
# Curie       21582
# Easley      14715
# Florence     8562
# Name: name, dtype: int64

# %% [markdown]
# Darden has the most overall impressions on the website.

# %% [markdown]
# ## Question 3
#
# Are there students who, when active, hardly access the curriculum? If so, what information do you have about these students?

# %%
df.groupby('user_id').endpoint.count().mean()
# Out:
# 917.65749235474

# %%
df.groupby('user_id').endpoint.count().median()
# Out:
# 692.0

# %% [markdown]
# The average student has around 900 impressions. It appears the average is skewed toward the high end by a few users that access the curriculum thouands of times. The median for student engagement is around 700. I will pick an arbitrary cutoff of 10 unique webpage visits for active students that hardly access the curriculum.

# %%
df['date'] = pd.to_datetime(df['date'], infer_datetime_format=True)

# %%
df['start_date'] = pd.to_datetime(df['start_date'], infer_datetime_format=True)
df['end_date'] = pd.to_datetime(df['end_date'], infer_datetime_format=True)

# %%
df[(df['date'] > df['start_date']) & (df['date'] < df['end_date'])]
# Out:
#              date      time                               endpoint  user_id  \
# 4      2018-01-26  09:56:24              javascript-i/conditionals        2
# 5      2018-01-26  09:56:41                     javascript-i/loops        2
# 6      2018-01-26  09:56:46              javascript-i/conditionals        3
# 7      2018-01-26  09:56:48                 javascript-i/functions        3
# 8      2018-01-26  09:56:59                     javascript-i/loops        2
# ...           ...       ...                                    ...      ...
# 900210 2021-04-21  16:36:09                   jquery/personal-site      869
# 900211 2021-04-21  16:36:34  html-css/css-ii/bootstrap-grid-system      948
# 900212 2021-04-21  16:37:48                               java-iii      834
# 900213 2021-04-21  16:38:14                      java-iii/servlets      834
# 900217 2021-04-21  16:41:51           javascript-i/bom-and-dom/dom      875
#
#         cohort_id              ip     name     slack start_date   end_date  \
# 4            22.0    97.105.19.61    Teddy    #teddy 2018-01-08 2018-05-17
# 5            22.0    97.105.19.61    Teddy    #teddy 2018-01-08 2018-05-17
# 6            22.0    97.105.19.61    Teddy    #teddy 2018-01-08 2018-05-17
# 7            22.0    97.105.19.61    Teddy    #teddy 2018-01-08 2018-05-17
# 8            22.0    97.105.19.61    Teddy    #teddy 2018-01-08 2018-05-17
# ...           ...             ...      ...       ...        ...        ...
# 900210      135.0    136.50.98.51    Marco    #marco 2021-01-25 2021-07-19
# 900211      138.0  104.48.214.211  Neptune  #neptune 2021-03-15 2021-09-03
# 900212      134.0     67.11.50.23     Luna     #luna 2020-12-07 2021-06-08
# 900213      134.0     67.11.50.23     Luna     #luna 2020-12-07 2021-06-08
# 900217      135.0  24.242.150.231    Marco    #marco 2021-01-25 2021-07-19
#
#                  created_at           updated_at        module  \
# 4       2018-01-08 13:59:10  2018-01-08 13:59:10  javascript-i
# 5       2018-01-08 13:59:10  2018-01-08 13:59:10  javascript-i
# 6       2018-01-08 13:59:10  2018-01-08 13:59:10  javascript-i
# 7       2018-01-08 13:59:10  2018-01-08 13:59:10  javascript-i
# 8       2018-01-08 13:59:10  2018-01-08 13:59:10  javascript-i
# ...                     ...                  ...           ...
# 900210  2021-01-20 21:31:11  2021-01-20 21:31:11        jquery
# 900211  2021-03-15 19:57:09  2021-03-15 19:57:09      html-css
# 900212  2020-12-07 16:58:43  2020-12-07 16:58:43      java-iii
# 900213  2020-12-07 16:58:43  2020-12-07 16:58:43      java-iii
# 900217  2021-01-20 21:31:11  2021-01-20 21:31:11  javascript-i
#
#                        lesson  is_lesson program_type
# 4                conditionals       True         Java
# 5                       loops       True         Java
# 6                conditionals       True         Java
# 7                   functions       True         Java
# 8                       loops       True         Java
# ...                       ...        ...          ...
# 900210          personal-site       True         Java
# 900211  bootstrap-grid-system       True         Java
# 900212               java-iii      False         Java
# 900213               servlets       True         Java
# 900217                    dom       True         Java
#
# [644386 rows x 16 columns]

# %%
df_active = df[(df['date'] > df['start_date']) & (df['date'] < df['end_date'])]

# %%
df_active.shape
# Out:
# (644386, 16)

# %%
df_active.groupby('user_id').user_id.count()
# Out:
# user_id
# 2      1541
# 3      1514
# 4       692
# 5      1621
# 6      1311
#        ...
# 976      25
# 977      76
# 978      49
# 979     104
# 981      42
# Name: user_id, Length: 724, dtype: int64

# %%
df_active.groupby('user_id').user_id.count() <= 10
# Out:
# user_id
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
#        ...
# 976    False
# 977    False
# 978    False
# 979    False
# 981    False
# Name: user_id, Length: 724, dtype: bool

# %%
df_active.groupby('user_id').user_id.count()[df_active.groupby('user_id').user_id.count() <= 10]
# Out:
# user_id
# 278    4
# 388    8
# 679    3
# 812    7
# 832    3
# 879    1
# 956    5
# Name: user_id, dtype: int64

# %%
df_active[df_active['user_id'] == 679]
# Out:
#              date      time                                  endpoint  \
# 597685 2020-07-14  08:05:15  1-fundamentals/1.1-intro-to-data-science
# 597686 2020-07-14  08:05:15      1-fundamentals/AI-ML-DL-timeline.jpg
# 597687 2020-07-14  08:05:15  1-fundamentals/modern-data-scientist.jpg
#
#         user_id  cohort_id             ip    name    slack start_date  \
# 597685      679       59.0  24.28.146.155  Darden  #darden 2020-07-13
# 597686      679       59.0  24.28.146.155  Darden  #darden 2020-07-13
# 597687      679       59.0  24.28.146.155  Darden  #darden 2020-07-13
#
#          end_date           created_at           updated_at          module  \
# 597685 2021-01-12  2020-07-13 18:32:19  2020-07-13 18:32:19  1-fundamentals
# 597686 2021-01-12  2020-07-13 18:32:19  2020-07-13 18:32:19  1-fundamentals
# 597687 2021-01-12  2020-07-13 18:32:19  2020-07-13 18:32:19  1-fundamentals
#
#                            lesson  is_lesson program_type
# 597685  1.1-intro-to-data-science       True           DS
# 597686      AI-ML-DL-timeline.jpg       True           DS
# 597687  modern-data-scientist.jpg       True           DS

# %%
inactive_list = list(df_active.groupby('user_id').user_id.count()[df_active.groupby('user_id').user_id.count() <= 10].index)

inactive_users = pd.DataFrame()

for user in inactive_list:
    
    temp_df = df_active[df_active['user_id'] == user]
    
    inactive_users = pd.concat([inactive_users, temp_df], axis=0)
    
inactive_users.reset_index(drop=True, inplace=True)

inactive_users
# Out:
#          date      time                                   endpoint  user_id  \
# 0  2018-09-27  13:57:44                                          /      278
# 1  2018-09-27  14:47:37                             java-ii/arrays      278
# 2  2018-09-27  14:58:48                             java-ii/arrays      278
# 3  2018-09-27  14:59:07                        java-ii/collections      278
# 4  2019-03-19  09:50:19                                          /      388
# 5  2019-03-19  09:50:23                                   html-css      388
# 6  2019-03-19  09:50:28                          html-css/elements      388
# 7  2019-03-19  10:04:11                          html-css/elements      388
# 8  2019-03-19  10:19:32                          html-css/elements      388
# 9  2019-03-19  11:11:51                             html-css/forms      388
# 10 2019-03-19  11:12:02                          html-css/elements      388
# 11 2019-03-19  12:19:23                          html-css/elements      388
# 12 2020-07-14  08:05:15   1-fundamentals/1.1-intro-to-data-science      679
# 13 2020-07-14  08:05:15       1-fundamentals/AI-ML-DL-timeline.jpg      679
# 14 2020-07-14  08:05:15   1-fundamentals/modern-data-scientist.jpg      679
# 15 2020-11-08  01:45:34    html-css/css-i/selectors-and-properties      812
# 16 2020-11-08  01:45:41                          html-css/elements      812
# 17 2020-11-08  01:45:56                html-css/css-i/introduction      812
# 18 2020-11-08  01:46:01                             html-css/css-i      812
# 19 2020-11-08  01:46:04                             html-css/forms      812
# 20 2020-11-08  01:46:06                          html-css/elements      812
# 21 2020-11-08  01:46:07                                   html-css      812
# 22 2020-12-07  14:22:00                                          /      832
# 23 2020-12-07  14:22:38                               javascript-i      832
# 24 2020-12-07  14:22:39                                   html-css      832
# 25 2021-01-26  12:21:18                                          /      879
# 26 2021-04-15  14:54:05                                          /      956
# 27 2021-04-15  14:54:10                                        toc      956
# 28 2021-04-15  14:55:05        javascript-i/introduction/operators      956
# 29 2021-04-15  14:56:04  javascript-i/introduction/primitive-types      956
# 30 2021-04-15  15:32:22        javascript-i/introduction/operators      956
#
#     cohort_id               ip       name       slack start_date   end_date  \
# 0        24.0     97.105.19.58  Voyageurs  #voyageurs 2018-05-29 2018-10-11
# 1        24.0     107.77.217.9  Voyageurs  #voyageurs 2018-05-29 2018-10-11
# 2        24.0     107.77.217.9  Voyageurs  #voyageurs 2018-05-29 2018-10-11
# 3        24.0     107.77.217.9  Voyageurs  #voyageurs 2018-05-29 2018-10-11
# 4        31.0     97.105.19.58  Andromeda  #andromeda 2019-03-18 2019-07-30
# 5        31.0     97.105.19.58  Andromeda  #andromeda 2019-03-18 2019-07-30
# 6        31.0     97.105.19.58  Andromeda  #andromeda 2019-03-18 2019-07-30
# 7        31.0     97.105.19.58  Andromeda  #andromeda 2019-03-18 2019-07-30
# 8        31.0     97.105.19.58  Andromeda  #andromeda 2019-03-18 2019-07-30
# 9        31.0     97.105.19.58  Andromeda  #andromeda 2019-03-18 2019-07-30
# 10       31.0     97.105.19.58  Andromeda  #andromeda 2019-03-18 2019-07-30
# 11       31.0     97.105.19.58  Andromeda  #andromeda 2019-03-18 2019-07-30
# 12       59.0    24.28.146.155     Darden     #darden 2020-07-13 2021-01-12
# 13       59.0    24.28.146.155     Darden     #darden 2020-07-13 2021-01-12
# 14       59.0    24.28.146.155     Darden     #darden 2020-07-13 2021-01-12
# 15       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 16       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 17       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 18       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 19       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 20       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 21       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 22       62.0     69.154.52.98    Jupiter    #jupiter 2020-09-21 2021-03-30
# 23       62.0     69.154.52.98    Jupiter    #jupiter 2020-09-21 2021-03-30
# 24       62.0     69.154.52.98    Jupiter    #jupiter 2020-09-21 2021-03-30
# 25      135.0    136.50.50.187      Marco      #marco 2021-01-25 2021-07-19
# 26      139.0  162.200.114.251     Oberon     #oberon 2021-04-12 2021-10-01
# 27      139.0  162.200.114.251     Oberon     #oberon 2021-04-12 2021-10-01
# 28      139.0  162.200.114.251     Oberon     #oberon 2021-04-12 2021-10-01
# 29      139.0  162.200.114.251     Oberon     #oberon 2021-04-12 2021-10-01
# 30      139.0  162.200.114.251     Oberon     #oberon 2021-04-12 2021-10-01
#
#              created_at           updated_at          module  \
# 0   2018-05-25 22:25:57  2018-05-25 22:25:57
# 1   2018-05-25 22:25:57  2018-05-25 22:25:57         java-ii
# 2   2018-05-25 22:25:57  2018-05-25 22:25:57         java-ii
# 3   2018-05-25 22:25:57  2018-05-25 22:25:57         java-ii
# 4   2019-03-18 20:35:06  2019-03-18 20:35:06
# 5   2019-03-18 20:35:06  2019-03-18 20:35:06        html-css
# 6   2019-03-18 20:35:06  2019-03-18 20:35:06        html-css
# 7   2019-03-18 20:35:06  2019-03-18 20:35:06        html-css
# 8   2019-03-18 20:35:06  2019-03-18 20:35:06        html-css
# 9   2019-03-18 20:35:06  2019-03-18 20:35:06        html-css
# 10  2019-03-18 20:35:06  2019-03-18 20:35:06        html-css
# 11  2019-03-18 20:35:06  2019-03-18 20:35:06        html-css
# 12  2020-07-13 18:32:19  2020-07-13 18:32:19  1-fundamentals
# 13  2020-07-13 18:32:19  2020-07-13 18:32:19  1-fundamentals
# 14  2020-07-13 18:32:19  2020-07-13 18:32:19  1-fundamentals
# 15  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 16  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 17  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 18  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 19  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 20  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 21  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 22  2020-09-21 18:06:27  2020-09-21 18:06:27
# 23  2020-09-21 18:06:27  2020-09-21 18:06:27    javascript-i
# 24  2020-09-21 18:06:27  2020-09-21 18:06:27        html-css
# 25  2021-01-20 21:31:11  2021-01-20 21:31:11
# 26  2021-04-12 18:07:21  2021-04-12 18:07:21
# 27  2021-04-12 18:07:21  2021-04-12 18:07:21             toc
# 28  2021-04-12 18:07:21  2021-04-12 18:07:21    javascript-i
# 29  2021-04-12 18:07:21  2021-04-12 18:07:21    javascript-i
# 30  2021-04-12 18:07:21  2021-04-12 18:07:21    javascript-i
#
#                        lesson  is_lesson program_type
# 0                                  False         Java
# 1                      arrays       True         Java
# 2                      arrays       True         Java
# 3                 collections       True         Java
# 4                                  False         Java
# 5                    html-css      False         Java
# 6                    elements       True         Java
# 7                    elements       True         Java
# 8                    elements       True         Java
# 9                       forms       True         Java
# 10                   elements       True         Java
# 11                   elements       True         Java
# 12  1.1-intro-to-data-science       True           DS
# 13      AI-ML-DL-timeline.jpg       True           DS
# 14  modern-data-scientist.jpg       True           DS
# 15   selectors-and-properties       True         Java
# 16                   elements       True         Java
# 17               introduction       True         Java
# 18                      css-i       True         Java
# 19                      forms       True         Java
# 20                   elements       True         Java
# 21                   html-css      False         Java
# 22                                 False         Java
# 23               javascript-i      False         Java
# 24                   html-css      False         Java
# 25                                 False         Java
# 26                                 False         Java
# 27                        toc      False         Java
# 28                  operators       True         Java
# 29            primitive-types       True         Java
# 30                  operators       True         Java

# %%
inactive_users.name.unique()
# Out:
# array(['Voyageurs', 'Andromeda', 'Darden', 'Hyperion', 'Jupiter', 'Marco',
#        'Oberon'], dtype=object)

# %%
inactive_users.name.nunique(), inactive_users.user_id.nunique()
# Out:
# (7, 7)

# %% [markdown]
# Each user in this dataframe is associated with a unique cohort, and each user is only associated with one cohort.

# %%
inactive_users.groupby('user_id').program_type.unique().value_counts()
# Out:
# [Java]    6
# [DS]      1
# Name: program_type, dtype: int64

# %% [markdown]
# Six of the accounts are associated with Java web development programs and one account is associated with the data science program.

# %%
inactive_users.groupby('user_id').date.first(), inactive_users.groupby('user_id').date.last()
# Out:
# (user_id
#  278   2018-09-27
#  388   2019-03-19
#  679   2020-07-14
#  812   2020-11-08
#  832   2020-12-07
#  879   2021-01-26
#  956   2021-04-15
#  Name: date, dtype: datetime64[ns],
#  user_id
#  278   2018-09-27
#  388   2019-03-19
#  679   2020-07-14
#  812   2020-11-08
#  832   2020-12-07
#  879   2021-01-26
#  956   2021-04-15
#  Name: date, dtype: datetime64[ns])

# %% [markdown]
# The first and last dates match for every user in this group. Curious...

# %%
inactive_users.groupby('user_id').date.last() - inactive_users.groupby('user_id').date.first()
# Out:
# user_id
# 278   0 days
# 388   0 days
# 679   0 days
# 812   0 days
# 832   0 days
# 879   0 days
# 956   0 days
# Name: date, dtype: timedelta64[ns]

# %% [markdown]
# Sure enough! All users in this group are accessing the curriculum on one day and one day only!
#
# It doesn't make sense for a student who is part of a 5-6 month long course to access the curriculum on one day.

# %%
inactive_users.groupby('ip').name.unique()
# Out:
# ip
# 107.77.217.9                  [Voyageurs]
# 136.50.50.187                     [Marco]
# 162.200.114.251                  [Oberon]
# 24.243.49.105                  [Hyperion]
# 24.28.146.155                    [Darden]
# 69.154.52.98                    [Jupiter]
# 97.105.19.58       [Voyageurs, Andromeda]
# Name: name, dtype: object

# %% [markdown]
# There's an ip address associated with two different cohorts! My theory is that these are "dummy" student accounts created by instructors to check out how the curriculum works/operates from the students' point of view.

# %%
inactive_users['ip'].isin(df[df['name'] == 'Staff']['ip'])
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# Name: ip, dtype: bool

# %%
inactive_users[inactive_users['ip'].isin(df[df['name'] == 'Staff']['ip'])]
# Out:
#          date      time           endpoint  user_id  cohort_id            ip  \
# 0  2018-09-27  13:57:44                  /      278       24.0  97.105.19.58
# 4  2019-03-19  09:50:19                  /      388       31.0  97.105.19.58
# 5  2019-03-19  09:50:23           html-css      388       31.0  97.105.19.58
# 6  2019-03-19  09:50:28  html-css/elements      388       31.0  97.105.19.58
# 7  2019-03-19  10:04:11  html-css/elements      388       31.0  97.105.19.58
# 8  2019-03-19  10:19:32  html-css/elements      388       31.0  97.105.19.58
# 9  2019-03-19  11:11:51     html-css/forms      388       31.0  97.105.19.58
# 10 2019-03-19  11:12:02  html-css/elements      388       31.0  97.105.19.58
# 11 2019-03-19  12:19:23  html-css/elements      388       31.0  97.105.19.58
#
#          name       slack start_date   end_date           created_at  \
# 0   Voyageurs  #voyageurs 2018-05-29 2018-10-11  2018-05-25 22:25:57
# 4   Andromeda  #andromeda 2019-03-18 2019-07-30  2019-03-18 20:35:06
# 5   Andromeda  #andromeda 2019-03-18 2019-07-30  2019-03-18 20:35:06
# 6   Andromeda  #andromeda 2019-03-18 2019-07-30  2019-03-18 20:35:06
# 7   Andromeda  #andromeda 2019-03-18 2019-07-30  2019-03-18 20:35:06
# 8   Andromeda  #andromeda 2019-03-18 2019-07-30  2019-03-18 20:35:06
# 9   Andromeda  #andromeda 2019-03-18 2019-07-30  2019-03-18 20:35:06
# 10  Andromeda  #andromeda 2019-03-18 2019-07-30  2019-03-18 20:35:06
# 11  Andromeda  #andromeda 2019-03-18 2019-07-30  2019-03-18 20:35:06
#
#              updated_at    module    lesson  is_lesson program_type
# 0   2018-05-25 22:25:57                          False         Java
# 4   2019-03-18 20:35:06                          False         Java
# 5   2019-03-18 20:35:06  html-css  html-css      False         Java
# 6   2019-03-18 20:35:06  html-css  elements       True         Java
# 7   2019-03-18 20:35:06  html-css  elements       True         Java
# 8   2019-03-18 20:35:06  html-css  elements       True         Java
# 9   2019-03-18 20:35:06  html-css     forms       True         Java
# 10  2019-03-18 20:35:06  html-css  elements       True         Java
# 11  2019-03-18 20:35:06  html-css  elements       True         Java

# %% [markdown]
# We have a match on the multiple accounts linked to the same ip! The users in the table above have the same ip address as a staff member!

# %%
inactive_users[~inactive_users['ip'].isin(df[df['name'] == 'Staff']['ip'])]
# Out:
#          date      time                                   endpoint  user_id  \
# 1  2018-09-27  14:47:37                             java-ii/arrays      278
# 2  2018-09-27  14:58:48                             java-ii/arrays      278
# 3  2018-09-27  14:59:07                        java-ii/collections      278
# 12 2020-07-14  08:05:15   1-fundamentals/1.1-intro-to-data-science      679
# 13 2020-07-14  08:05:15       1-fundamentals/AI-ML-DL-timeline.jpg      679
# 14 2020-07-14  08:05:15   1-fundamentals/modern-data-scientist.jpg      679
# 15 2020-11-08  01:45:34    html-css/css-i/selectors-and-properties      812
# 16 2020-11-08  01:45:41                          html-css/elements      812
# 17 2020-11-08  01:45:56                html-css/css-i/introduction      812
# 18 2020-11-08  01:46:01                             html-css/css-i      812
# 19 2020-11-08  01:46:04                             html-css/forms      812
# 20 2020-11-08  01:46:06                          html-css/elements      812
# 21 2020-11-08  01:46:07                                   html-css      812
# 22 2020-12-07  14:22:00                                          /      832
# 23 2020-12-07  14:22:38                               javascript-i      832
# 24 2020-12-07  14:22:39                                   html-css      832
# 25 2021-01-26  12:21:18                                          /      879
# 26 2021-04-15  14:54:05                                          /      956
# 27 2021-04-15  14:54:10                                        toc      956
# 28 2021-04-15  14:55:05        javascript-i/introduction/operators      956
# 29 2021-04-15  14:56:04  javascript-i/introduction/primitive-types      956
# 30 2021-04-15  15:32:22        javascript-i/introduction/operators      956
#
#     cohort_id               ip       name       slack start_date   end_date  \
# 1        24.0     107.77.217.9  Voyageurs  #voyageurs 2018-05-29 2018-10-11
# 2        24.0     107.77.217.9  Voyageurs  #voyageurs 2018-05-29 2018-10-11
# 3        24.0     107.77.217.9  Voyageurs  #voyageurs 2018-05-29 2018-10-11
# 12       59.0    24.28.146.155     Darden     #darden 2020-07-13 2021-01-12
# 13       59.0    24.28.146.155     Darden     #darden 2020-07-13 2021-01-12
# 14       59.0    24.28.146.155     Darden     #darden 2020-07-13 2021-01-12
# 15       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 16       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 17       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 18       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 19       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 20       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 21       58.0    24.243.49.105   Hyperion   #hyperion 2020-05-26 2020-11-10
# 22       62.0     69.154.52.98    Jupiter    #jupiter 2020-09-21 2021-03-30
# 23       62.0     69.154.52.98    Jupiter    #jupiter 2020-09-21 2021-03-30
# 24       62.0     69.154.52.98    Jupiter    #jupiter 2020-09-21 2021-03-30
# 25      135.0    136.50.50.187      Marco      #marco 2021-01-25 2021-07-19
# 26      139.0  162.200.114.251     Oberon     #oberon 2021-04-12 2021-10-01
# 27      139.0  162.200.114.251     Oberon     #oberon 2021-04-12 2021-10-01
# 28      139.0  162.200.114.251     Oberon     #oberon 2021-04-12 2021-10-01
# 29      139.0  162.200.114.251     Oberon     #oberon 2021-04-12 2021-10-01
# 30      139.0  162.200.114.251     Oberon     #oberon 2021-04-12 2021-10-01
#
#              created_at           updated_at          module  \
# 1   2018-05-25 22:25:57  2018-05-25 22:25:57         java-ii
# 2   2018-05-25 22:25:57  2018-05-25 22:25:57         java-ii
# 3   2018-05-25 22:25:57  2018-05-25 22:25:57         java-ii
# 12  2020-07-13 18:32:19  2020-07-13 18:32:19  1-fundamentals
# 13  2020-07-13 18:32:19  2020-07-13 18:32:19  1-fundamentals
# 14  2020-07-13 18:32:19  2020-07-13 18:32:19  1-fundamentals
# 15  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 16  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 17  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 18  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 19  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 20  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 21  2020-05-26 19:22:44  2020-05-26 19:22:44        html-css
# 22  2020-09-21 18:06:27  2020-09-21 18:06:27
# 23  2020-09-21 18:06:27  2020-09-21 18:06:27    javascript-i
# 24  2020-09-21 18:06:27  2020-09-21 18:06:27        html-css
# 25  2021-01-20 21:31:11  2021-01-20 21:31:11
# 26  2021-04-12 18:07:21  2021-04-12 18:07:21
# 27  2021-04-12 18:07:21  2021-04-12 18:07:21             toc
# 28  2021-04-12 18:07:21  2021-04-12 18:07:21    javascript-i
# 29  2021-04-12 18:07:21  2021-04-12 18:07:21    javascript-i
# 30  2021-04-12 18:07:21  2021-04-12 18:07:21    javascript-i
#
#                        lesson  is_lesson program_type
# 1                      arrays       True         Java
# 2                      arrays       True         Java
# 3                 collections       True         Java
# 12  1.1-intro-to-data-science       True           DS
# 13      AI-ML-DL-timeline.jpg       True           DS
# 14  modern-data-scientist.jpg       True           DS
# 15   selectors-and-properties       True         Java
# 16                   elements       True         Java
# 17               introduction       True         Java
# 18                      css-i       True         Java
# 19                      forms       True         Java
# 20                   elements       True         Java
# 21                   html-css      False         Java
# 22                                 False         Java
# 23               javascript-i      False         Java
# 24                   html-css      False         Java
# 25                                 False         Java
# 26                                 False         Java
# 27                        toc      False         Java
# 28                  operators       True         Java
# 29            primitive-types       True         Java
# 30                  operators       True         Java

# %% [markdown]
# Although these examples don't have matching ip addresses with known staff members, they follow a similar pattern of behavior. The account is created at the beginning of a cohort, it's used for one day during the class, and then it's never active again. Looking at the account activity, I believe the instructors are using these accounts to check the availability/version of certain pages of the website to make sure they are displayed correctly to the students.

# %% [markdown]
# ## Question 4
#
# Is there any suspicious activity, such as users/machines/etc accessing the curriculum who shouldn’t be? Does it appear that any web-scraping is happening? Are there any suspicious IP addresses?
